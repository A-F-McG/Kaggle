# %%
#Invite everyone to the data science par-tay

import pandas as pd

from ipywidgets import widgets

# %% [markdown]
# # Predicting suicide rates based on supposed risk factors

# %% [markdown]
# Mental health is a prevalent problem in today's world. Being able to predict the percentage of a population in a region who will commit suicide could lead to more money for support being put in place in those regions and for those most at risk.
#
# I have looked at some of the risk factors for suicide listed on mentalhealth.org (https://www.mentalhealth.org.uk/a-to-z/s/suicide) and have chosen to investigate whether unemployment, alcohol consumption, poverty and murder rates are able to predict suicide rates.

# %%
# Out:
# RadioButtons(description='So, your name is Alice?', options=('yes', 'no'), style=DescriptionStyle(description_…

# %%
# Out:
# Sorry, my bad!

# %% [markdown]
# # Gathering and preprocessing the data

# %%
unemployment = pd.read_csv("long_term_unemployment_rate_percent (1).csv")

unemployment.head()
# Out:
#      country  1990  1991  1992  1993  1994  1995  1996  1997  1998  ...   \
# 0    Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1    Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2     Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3  Argentina   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4    Armenia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    2008   2009  2010  2011  2012  2013  2014  2015  2016  2017
# 0  4.50  4.910  5.67  5.28  5.30  5.53  5.76  6.09   NaN   NaN
# 1   NaN    NaN   NaN   NaN   NaN   NaN  2.15   NaN   NaN   NaN
# 2   NaN    NaN   NaN  1.56   NaN   NaN   NaN   NaN   NaN   NaN
# 3  0.88  0.925  1.22  1.11  1.28  1.04  1.22   NaN   NaN  1.14
# 4   NaN  5.690  6.77  6.46  5.80   NaN  7.15  7.11   5.4   NaN
#
# [5 rows x 29 columns]

# %%
unemployment.transpose().head()
# Out:
#              0        1       2          3        4          5        6    \
# country  Albania  Algeria  Angola  Argentina  Armenia  Australia  Austria
# 1990         NaN      NaN     NaN        NaN      NaN       1.24      NaN
# 1991         NaN      NaN     NaN        NaN      NaN       1.94      NaN
# 1992         NaN      NaN     NaN        NaN      NaN       2.66      NaN
# 1993         NaN      NaN     NaN        NaN      NaN       2.71      NaN
#
#                 7           8        9      ...         111  \
# country  Azerbaijan  Bangladesh  Belarus    ...     Ukraine
# 1990            NaN         NaN      NaN    ...         NaN
# 1991            NaN         NaN      NaN    ...         NaN
# 1992            NaN         NaN      NaN    ...         NaN
# 1993            NaN         NaN      NaN    ...         NaN
#
#                           112             113            114      115  \
# country  United Arab Emirates  United Kingdom  United States  Uruguay
# ...

# %%
rural_poverty = pd.read_csv("rural_poverty_percent_rural_people_below_national_rural.csv")
rural_poverty.head()
# Out:
#        country  1985  1986  1987  1988  1989  1990  1991  1992  1993  ...   \
# 0  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2      Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3       Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4      Armenia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0   NaN  38.2   NaN   NaN   NaN  38.3   NaN   NaN   NaN   NaN
# 1   NaN   NaN  14.6   NaN   NaN   NaN  15.3   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   4.8   NaN   NaN   NaN   NaN
# 3   NaN   NaN  58.3   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN  27.5  34.9  36.0  34.5  32.1  31.7  29.9   NaN
#
# [5 rows x 32 columns]

# %%
le = pd.melt(rural_poverty, id_vars=['country'])

le2 = le.rename(columns={'variable':'year','value':'rural_poverty_percentage'})
#le2 = le2.sort(['country','year'])
le2.sort_values(by=["country"]).reset_index()
# Out:
#       index      country  year  rural_poverty_percentage
# 0         0  Afghanistan  1985                       NaN
# 1      2850  Afghanistan  2015                       NaN
# 2        95  Afghanistan  1986                       NaN
# 3      1330  Afghanistan  1999                       NaN
# 4      1615  Afghanistan  2002                       NaN
# 5      2755  Afghanistan  2014                       NaN
# 6       190  Afghanistan  1987                       NaN
# 7      1235  Afghanistan  1998                       NaN
# 8      1710  Afghanistan  2003                       NaN
# 9      2660  Afghanistan  2013                       NaN
# 10      285  Afghanistan  1988                       NaN
# 11     1140  Afghanistan  1997                       NaN
# 12     1805  Afghanistan  2004                       NaN
# 13      380  Afghanistan  1989                       NaN
# 14     1045  Afghanistan  1996                       NaN
# ...
